# %%
#Button
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")

def btn_print():
    print("Hello-GUI")
btn1=Button(root, command=btn_print,text="OK", width="20", height="10", font="30", bg="black", fg="white", padx=20, pady=50)
btn1.pack()
btn2=Button(root,text="Reset")
btn2.pack()
root.mainloop()

# %%
#Label

from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
def label_show():
    lb1["text"]="Alaa Karem"
    lb1["bg"]="blue"
lb1=Label(root, text="Enter you name", width="10", height="1", font="30", bg="green", fg="white", padx=20, pady=50)
lb1.pack()

btn2=Button(root, command=label_show,text="", width="40", height="0", font="30", bg="black", fg="white", padx=20, pady=50)
btn2.pack()
root.mainloop()

# %%
#Text

from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
txt1=Text(root,width="50", height="1", font="30", bg="black", fg="white", padx=20, pady=50)
txt1.pack()
def label_show():
    name=txt1.get("1.0","end")
    lb3["text"]=name
btn3=Button(root, command=label_show,text="", width="40", height="0", font="30", bg="black", fg="white", padx=20, pady=50)
btn3.pack()
lb3=Label(root, width="40", height="0", font="30", bg="black", fg="white", padx=20, pady=50)
lb3.pack()
root.mainloop()

# %%
#Frame
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
fr1=Frame(root,bg="red")
btn3=Button(fr1, text="", width="10", height="10", font="30", bg="black", fg="white", padx=20, pady=50)
lb3=Label(fr1, width="10", height="10", font="30", bg="black", fg="white", padx=20, pady=50)
fr1.pack()
btn3.pack()
lb3.pack()
root.mainloop()

# %%
#Pack-Options
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
fr1=Frame(root)
btn1=Button(fr1,text="Button1")
fr2=Frame(root)
btn2=Button(fr2,text="Button2")
fr3=Frame(root)
btn3=Button(fr3,text="Button3")
fr4=Frame(root)
btn4=Button(fr4,text="Button4")
btn1.pack()
btn2.pack()
btn3.pack()
btn4.pack()
fr1.pack(side=TOP)                                                 # I can use Grid instead pack(side)
fr2.pack(side=BOTTOM)
fr3.pack(side=RIGHT)
fr4.pack(side=LEFT)
root.mainloop()

# %%
#Grid
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
fr1=Frame(root)
btn1=Button(fr1,text="Button1")
fr2=Frame(root)
btn2=Button(fr2,text="Button2")
fr3=Frame(root)
btn3=Button(fr3,text="Button3")
fr4=Frame(root)
btn4=Button(fr4,text="Button4")
btn1.pack()
btn2.pack()
btn3.pack()
btn4.pack()
fr1.grid(column=1,row=1)
fr2.grid(column=2,row=1)
fr3.grid(column=3,row=1)
fr4.grid(column=4,row=1)
root.mainloop()

# %%
#Place
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
btn1=Button(root,text="Button1")
btn1.pack()
btn1.place(anchor=NW,width=100,height=100,bordermode=OUTSIDE,)
root.mainloop()

# %%
#LabelFrame
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
lbfr1=LabelFrame(root,text="This is label frame")
lbfr1.pack(expand="yes",fill="both")
lb1=Label(lbfr1,text="This is label")
lb1.pack()
root.mainloop()

# %%
#Checkbutton
from tkinter import *
root=Tk()
root.geometry("800x500")
root.title("alaa")
def hello():
    print("hello world")
checkbtn=Checkbutton(root,text="Auto-save",font=14, bg="blue", command=hello, state=DISABLED, onvalue=1, offvalue=0)
checkbtn.pack()
root.mainloop()

# %%
#Radiobutton
from tkinter import *
root=Tk()
root.geometry("10x10")
root.title("alaa")
rdbtn1=Radiobutton(root,text="Formal",value=1)
rdbtn2=Radiobutton(root,text="Not-Formal",value=2)
rdbtn1.pack()
rdbtn2.pack()
root.mainloop()

# %%
#Listbox
from tkinter import *
root=Tk()
root.geometry("500x500")
root.title("alaa")
lbbox1=Listbox(root)
lbbox1.insert(1,"choice 1")
lbbox1.insert(2,"choice 2")
lbbox1.insert(3,"choice 3")
lbbox1.insert(4,"choice 4")
lbbox1.insert(5,"choice 5")
lbbox1.pack()
def check():
    str=lbbox1.get(ACTIVE)
    if(str=="choice 1"):
        print("choice 1")
    elif(str=="choice 2"):
        print("choice 2")
    elif(str=="choice 3"):
        print("choice 3")
    elif(str=="choice 4"):
        print("choice 4")
    else:
        print("choice 5")
        
btncheck=Button(root,text="submit",comman=check,bg="green")
btncheck.pack()
root.mainloop()

# %%
from tkinter import ttk
import tkinter as tk

main_window = tk.Tk()
main_window.config(width=300, height=200)
main_window.title("Combobox")
def selection_changed(event):
    selection = combo.get()
    messagebox.showinfo(
        title="New Selection",
        message=f"Selected option: {selection}"
    )
combo = ttk.Combobox(
    state="readonly",
    values=["Python", "C", "C++", "Java"]
)
combo.bind("<<ComboboxSelected>>", selection_changed)
combo.place(x=50, y=50)
main_window.mainloop()

# %%
#Entry        // the same Text but it enter single line
from tkinter import *
root=Tk()
root.geometry("500x500")
root.title("alaa")
txt1=Entry(root)
txt1.pack()
root.mainloop()

# %%
#PanedWindow  // it's a container that contains all elements
from tkinter import *
root=Tk()
root.geometry("500x500")
root.title("alaa")
m1=PanedWindow()
m1.pack(fill=BOTH, expand=1)
left=Label(m1,text="left")
m1.add(left)
m2=PanedWindow(m1,orient=VERTICAL)
m1.add(m2)
top=Label(m2,text="top")
m2.add(top)
bottom=Label(m2,text="bottom")
m2.add(bottom)
root.mainloop()

# %%
#TopLevel
from tkinter import *
root=Tk()
root.geometry("500x500")
root.title("alaa")
TL=Toplevel()
btn=Button(TL,text="buttonTest")
btn.pack()
TL.mainloop()
root.mainloop()

# %%
#MenueBar
from tkinter import *
root=Tk()
root.geometry("500x500")
root.title("alaa")
def donothing():
    filewindow=Toplevel(root)
    btn=Button(filewindow,text="Do nothing button")
    button.pack()
menubar=Menu(root)
filemenu=Menu(menubar,tearoff=0)
filemenu.add_command(label="New",command=donothing)
filemenu.add_command(label="Open",command=donothing)
filemenu.add_command(label="Save",command=donothing)
filemenu.add_command(label="Save as",command=donothing)
filemenu.add_command(label="Close",command=donothing)
filemenu.add_separator()
filemenu.add_command(label="Exit",command=root.quit)
menubar.add_cascade(label="File",menu=filemenu)

editmenu=Menu(menubar,tearoff=0)
editmenu.add_command(label="Undo",command=donothing)
editmenu.add_separator()
editmenu.add_command(label="Cut",command=donothing)
editmenu.add_command(label="Copy",command=donothing)
editmenu.add_command(label="Paste",command=donothing)
editmenu.add_command(label="Delete",command=donothing)
editmenu.add_command(label="Select All",command=donothing)
menubar.add_cascade(label="Edit",menu=editmenu)

helpmenu=Menu(menubar,tearoff=0)
helpmenu.add_command(label="Help Index",command=donothing)
helpmenu.add_command(label="About..",command=donothing)
helpmenu.add_command(label="Help",command=donothing)
menubar.add_cascade(label="Help",menu=helpmenu)

root.config(menu=menubar)

root.mainloop()
