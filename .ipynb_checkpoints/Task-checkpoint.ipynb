# %%
import pandas as pd
import numpy as np
from tkinter import *
from tkinter import simpledialog
import tkinter as tk
from tkinter import filedialog
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression , Lasso
from sklearn.model_selection import train_test_split
from sklearn import metrics
# Define the root window
root = tk.Tk()
root.geometry("1000x700")
root.title("Task")
W = root.winfo_screenwidth()
H = root.winfo_screenheight()

frame = tk.Frame(root, bg="MediumAquamarine", width=1000, height=700) 
frame.grid(row=0, column=0)
frame.place(x=0, y=0, width=W, height=H)

data=None
#/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\

def chooseFile():
    filepath=filedialog.askopenfilename(initialdir="‪C:\\Users\\alaak\\Section_ML",title="choose file",
                                        filetypes=(("Csv files","*.csv"),("all files","*.*")) )
    file= open(filepath,'r')
    global data
    data = pd.read_csv(file)
    
#/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\

def dataTable():
    tableData = tk.Label(frame,text="data", width="40",font="10",height="20", bg="MediumSeaGreen")
    tableData.grid(column=1, row=1, sticky="w", pady=15)
    tableData.place(x=50,y=270)
    dataframe1 = pd.DataFrame(data)
    tableData["text"]=dataframe1
    dataframe1
    
#/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\   

def dataDescription():
    decriptionData = tk.Label(frame,text="data", width="40",font="10",height="20", bg="MediumSeaGreen")
    decriptionData.grid(column=2, row=1, sticky="w", pady=15)
    decriptionData.place(x=550,y=270)
    decriptionData["text"]=data.describe()
    
#/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\

def linearRegression():
    newFrame = Toplevel(root, bg="MediumAquamarine")
    newFrame.title("Regression Frame")
    newFrame.geometry("500x500")
    labelSpecifiedRate = tk.Label(newFrame, text="Specify test_size",width="19",font="10",height="3",fg = "black", bg="MediumSeaGreen")
    labelSpecifiedRate.grid(row=0, column=1, sticky="w", pady=15)
    labelSpecifiedRate.place(x=50,y=30)

    v2 = DoubleVar()
    def scalValue():
       val= (v2.get()/100)
       labelConfirmRate.config(text= val)
    scale = Scale( newFrame, variable=v2, from_=1, to=100, orient=HORIZONTAL, bg="MediumSeaGreen")
    scale.pack(anchor = CENTER) 
    scale.place(x=300,y=42)
    labelConfirmRate=tk.Label(newFrame,text="", width="11",font="10",height="2", bg="MediumSeaGreen")
    labelConfirmRate.grid(row=2, column=1, sticky="w", pady=15)
    labelConfirmRate.place(x=300,y=123)
    
    btnRate=tk.Button(newFrame,text="Confirm test_size",width="19",font="10",height="3",fg = "black", bg="MediumSeaGreen", command=scalValue)
    btnRate.grid(row=1, column=1, sticky="w", pady=15)
    btnRate.place(x=50,y=110)
    
    labelLearningRate = tk.Label(newFrame, text="Specify Random State",width="20",font="10",height="3",fg = "black", bg="MediumSeaGreen")
    labelLearningRate.grid(row=0, column=1, sticky="w", pady=15)
    labelLearningRate.place(x=50,y=198)
    
    textLearingRate=tk.Text(newFrame, width="11",font="10",height="2", bg="MediumSeaGreen")
    textLearingRate.grid(row=2, column=1, sticky="w", pady=15)
    textLearingRate.place(x=300,y=211)
    
    labelChooseTestError = tk.Label(newFrame, text="Choose to compare test",width="20",font="10",height="3",fg = "black", bg="MediumSeaGreen")
    labelChooseTestError.grid(row=0, column=1, sticky="w", pady=15)
    labelChooseTestError.place(x=50,y=310)
    
    def meanAbsoluteError():
        X=data.iloc[:,:-1].values
        y=data.iloc[:,-1].values
        from sklearn.model_selection import train_test_split
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=labelConfirmRate["text"], random_state= int(textLearingRate.get("1.0","end")) )
        from sklearn.linear_model import LinearRegression
        regressor = LinearRegression()
        regressor.fit(X_train, y_train)                                           
        y_pred = regressor.predict(X_test)
        df = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})                   
        from sklearn import metrics
        resultLinearRegression.config(text=metrics.mean_absolute_error(y_test, y_pred) )
        #print(metrics.mean_absolute_error(y_test, y_pred))
    def meanSquareError():
        X=data.iloc[:,:-1].values
        y=data.iloc[:,-1].values
        from sklearn.model_selection import train_test_split
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=labelConfirmRate["text"], random_state= int(textLearingRate.get("1.0","end")))
        from sklearn.linear_model import LinearRegression
        regressor = LinearRegression()
        regressor.fit(X_train, y_train)                                          
        y_pred = regressor.predict(X_test)
        df = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})                   
        from sklearn import metrics
        resultLinearRegression.config(text= metrics.mean_squared_error(y_test, y_pred))
    def rootMeanSquareError():
        X=data.iloc[:,:-1].values
        y=data.iloc[:,-1].values
        from sklearn.model_selection import train_test_split
        X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=labelConfirmRate["text"], random_state= int(textLearingRate.get("1.0","end")))
        from sklearn.linear_model import LinearRegression
        regressor = LinearRegression()
        regressor.fit(X_train, y_train)                                          
        y_pred = regressor.predict(X_test)
        df = pd.DataFrame({'Actual':y_test, 'Predicted':y_pred})                   
        from sklearn import metrics
        resultLinearRegression.config(text= np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
        
    rdbtn1=Radiobutton(newFrame,text="Mean Absolute Error",value=1, bg="MediumSeaGreen", command=meanAbsoluteError)
    rdbtn2=Radiobutton(newFrame,text="Mean Square Error",value=2, bg="MediumSeaGreen", command=meanSquareError)
    rdbtn3=Radiobutton(newFrame,text="Root Mean Square Error",value=3, bg="MediumSeaGreen", command=rootMeanSquareError)
    rdbtn1.place(x=300,y=300)
    rdbtn2.place(x=300,y=332)
    rdbtn3.place(x=300,y=364)
    
    resultLinearRegression = tk.Label(newFrame, text=" ", width="20",font="10",height="3",fg = "black", bg="MediumSeaGreen")
    resultLinearRegression.grid(row=0, column=1, sticky="w", pady=15)
    resultLinearRegression.place(x=130,y=417)
    
#/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\\/\
btnSelect = tk.Button(frame, text="Choose Dataset",width="15",font="10",height="3",fg = "black", bg="MediumSeaGreen", command=chooseFile)
btnSelect.grid(row=0, column=1, sticky="w", pady=15)
btnSelect.place(x=50,y=30)

btnRegression = tk.Button(frame, text="Regression",width="15",font="10",height="3",fg = "black", bg="MediumSeaGreen", command=linearRegression)
btnRegression.grid(row=0, column=1, sticky="w", pady=15)
btnRegression.place(x=550,y=30)

btnTable = tk.Button(frame, text="Table of data",width="15",font="10",height="3",fg = "black", bg="MediumSeaGreen", command=dataTable)
btnTable.grid(row=1, column=1, sticky="w", pady=15)
btnTable.place(x=50,y=150)

btnDescription = tk.Button(frame, text="Description of data",width="15",font="10",height="3",fg = "black", bg="MediumSeaGreen", command=dataDescription)
btnDescription.grid(row=1, column=2, sticky="w", pady=15)
btnDescription.place(x=550,y=150)



root.mainloop()

# %%
#Radiobutton
from tkinter import *
root=Tk()
root.geometry("10x10")
root.title("alaa")
rdbtn1=Radiobutton(root,text="Formal",value=1)
rdbtn2=Radiobutton(root,text="Not-Formal",value=2)
rdbtn1.pack()
rdbtn2.pack()
root.mainloop()

# %%
import pandas as pd
import numpy as np
from tkinter import *
from tkinter import simpledialog
import tkinter as tk
from tkinter import filedialog
from sklearn.linear_model import Ridge
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import LinearRegression , Lasso
from sklearn.model_selection import train_test_split
from sklearn import metrics
from IPython.display import display
data=pd.read_csv('dataset.csv')
#data.describe()
dataframe1 = pd.DataFrame(data)
dataframe1
# Out:
#      Time  radius  texture  perimeter    area  smoothness  compactness  \
# 0      31   18.02    27.60     117.50  1013.0     0.09489      0.10360
# 1      61   17.99    10.38     122.80  1001.0     0.11840      0.27760
# 2     116   21.37    17.44     137.50  1373.0     0.08836      0.11890
# 3     123   11.42    20.38      77.58   386.1     0.14250      0.28390
# 4      27   20.29    14.34     135.10  1297.0     0.10030      0.13280
# ..    ...     ...      ...        ...     ...         ...          ...
# 189     3   14.72    25.26      99.28   657.5     0.11740      0.21120
# 190    10   22.52    21.92     146.90  1597.0     0.07592      0.09162
# 191     8   15.44    31.18     101.00   740.4     0.09399      0.10620
# 192    12   17.17    29.19     110.00   915.3     0.08952      0.06655
# 193     6   16.70    28.13     110.30   885.4     0.08896      0.11310
#
#      concavity  'concave '  symmetry  fractal  'Mean Radius'       a      b  \
# ...

# %%
import tkinter as tk
from tkinter import *
from tkinter import ttk
my_w = tk.Tk()
my_w.geometry("400x200") 

# def my_upd(value):
#     prg1['value'] =my_scale1.get()

prg1 = ttk.Progressbar(my_w,orient = HORIZONTAL,
        length = 320, mode = 'determinate',maximum=100)        
prg1.grid(row=0,column=0,padx=20,pady=45)        

my_scale1 = tk.Scale(my_w, from_=0, to=100, orient='horizontal',command=my_upd,length=200)
my_scale1.grid(row=1,column=0) 
my_scale1.get()


my_w.mainloop()
